# %%
# !pip3 install requests

# %%
import requests
import pandas as pd
import re
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 都道府県内市区町村一覧取得API

# %%
#https://www.land.mlit.go.jp/webland/api.html
URL = 'https://www.land.mlit.go.jp/webland/api/TradeListSearch?'
from1 = 20221
to = 20222
area = 27
city = "西区"
station = "西長堀"

key = f"from={from1}&to={to}&area={area}"#&city='{city}'&station='{station}'"
# https://www.land.mlit.go.jp/webland/api/TradeListSearch?from=20151&to=20152&area=13

#API情報のすべて

response = requests.get(URL+key).json()
response
# Out:
# https://www.land.mlit.go.jp/webland/api/TradeListSearch?from=20221&to=20222&area=27
# {'status': 'OK',
#  'data': [{'Type': '中古マンション等',
#    'MunicipalityCode': '27102',
#    'Prefecture': '大阪府',
#    'Municipality': '大阪市都島区',
#    'DistrictName': '網島町',
#    'TradePrice': '20000000',
#    'FloorPlan': '１ＬＤＫ',
#    'Area': '20',
#    'BuildingYear': '令和2年',
#    'Structure': 'ＲＣ',
#    'Use': '住宅',
#    'Purpose': '住宅',
#    'CityPlanning': '第２種住居地域',
#    'CoverageRatio': '80',
#    'FloorAreaRatio': '300',
#    'Period': '2022年第２四半期',
#    'Renovation': '未改装'},
#   {'Type': '中古マンション等',
#    'MunicipalityCode': '27102',
#    'Prefecture': '大阪府',
#    'Municipality': '大阪市都島区',
#    'DistrictName': '網島町',
#    'TradePrice': '20000000',
#    'FloorPlan': '１Ｋ',
#    'Area': '20',
#    'BuildingYear': '令和2年',
#    'Structure': 'ＲＣ',
#    'Use': '住宅',
#    'Purpose': '住宅',
#    'CityPlanning': '第２種住居地域',
#    'CoverageRatio': '80',
#    'FloorAreaRatio': '300',
# ...
